# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_json("US_category_id.json") #.read_json is a function in the pandas package
print(df.head())
print(df.columns)
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# Index(['kind', 'etag', 'items'], dtype='object')

# %%
#example scatter chart from matplotlib: 
#https://matplotlib.org/stable/plot_types/basic/scatter_plot.html#sphx-glr-plot-types-basic-scatter-plot-py

import matplotlib.pyplot as plt
import numpy as np

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
#Look at the type of data stored and the headers of the data in the file

df=pd.read_csv("airlines_final.csv") #.read_csv is a function in the pandas package
print(df.head())
print(df.columns)
# Out:
#    Unnamed: 0    id        day      airline        destination    dest_region  \
# 0           0  1351    Tuesday  UNITED INTL             KANSAI           Asia
# 1           1   373     Friday       ALASKA  SAN JOSE DEL CABO  Canada/Mexico
# 2           2  2820   Thursday        DELTA        LOS ANGELES        West US
# 3           3  1157    Tuesday    SOUTHWEST        LOS ANGELES        West US
# 4           4  2992  Wednesday     AMERICAN              MIAMI        East US
#
#   dest_size boarding_area   dept_time  wait_min     cleanliness  \
# 0       Hub  Gates 91-102  12/31/2018       115           Clean
# 1     Small   Gates 50-59  12/31/2018       135           Clean
# 2       Hub   Gates 40-48  12/31/2018        70         Average
# 3       Hub   Gates 20-39  12/31/2018       190           Clean
# 4       Hub   Gates 50-59  12/31/2018       559  Somewhat clean
#
#           safety        satisfaction
# 0        Neutral      Very satisfied
# ...

# %%
#Information on the file loaded
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2477 entries, 0 to 2476
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2477 non-null   int64
#  1   id             2477 non-null   int64
#  2   day            2477 non-null   object
#  3   airline        2477 non-null   object
#  4   destination    2477 non-null   object
#  5   dest_region    2477 non-null   object
#  6   dest_size      2477 non-null   object
#  7   boarding_area  2477 non-null   object
#  8   dept_time      2477 non-null   object
#  9   wait_min       2477 non-null   int64
#  10  cleanliness    2477 non-null   object
#  11  safety         2477 non-null   object
#  12  satisfaction   2477 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 251.7+ KB

# %%
fig, ax=plt.subplots()
ax.plot(df["dept_time"], df["wait_min"])
ax.set_xticklabels(df["dept_time"], rotation=90)
plt.show()
# Out:
# C:\Users\Phillip\AppData\Local\Temp/ipykernel_15440/2888205341.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df["dept_time"], rotation=90)

# %%
airlines = np.unique(df["airline"])
print(airlines)
# Out:
# ['AER LINGUS' 'AEROMEXICO' 'AIR CANADA' 'AIR CHINA' 'AIR FRANCE/KLM'
#  'AIR NEW ZEALAND' 'ALASKA' 'AMERICAN' 'ANA ALL NIPPON' 'AVIANCA'
#  'BRITISH AIRWAYS' 'CATHAY PACIFIC' 'CHINA EASTERN' 'CHINA SOUTHERN'
#  'COPA' 'DELTA' 'EMIRATES' 'EVA AIR' 'FRONTIER' 'HAWAIIAN AIR' 'INTERJET'
#  'JETBLUE' 'KOREAN AIR' 'LUFTHANSA' 'PHILIPPINE AIRLINES' 'QANTAS'
#  'SINGAPORE AIRLINES' 'SOUTHWEST' 'TURKISH AIRLINES' 'UNITED'
#  'UNITED INTL' 'VIRGIN ATLANTIC' 'WOW']

# %%
fig, ax=plt.subplots()
x = df["dept_time"]
y = df["wait_min"]
sizes= df["wait_min"].count()
colors = airlines
ax.scatter(x, y, sizes)

plt.show()

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")

df_airlines=pd.read_csv("airlines_final.csv") #.read_csv is a function in the pandas package

# plot
fig, ax = plt.subplots(figsize=(10,10))

sns.scatterplot(x=df["airline"], y=df["wait_min"].mean(), hue=df["airline"])
# Out:
# <AxesSubplot:xlabel='airline'>
